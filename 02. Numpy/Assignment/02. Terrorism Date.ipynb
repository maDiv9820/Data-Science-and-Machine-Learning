# %%
import csv
import numpy as np
with open('/home/madiv/Data Science and Machine Learning/02. Numpy/terrorismData.csv') as file:
    data = list(csv.DictReader(file,skipinitialspace = True))
days,month,temp = [],[],[]
for info in data:
    if info['Year'] == '2010':
        days.append(info['Day'])
        month.append(info['Month'])
        temp.append(1)
days = np.array(days, dtype = int)
month = np.array(month, dtype = int)
temp = np.array(temp, dtype = int)
ans = temp[(days >= 1)&(days <= 31)]
