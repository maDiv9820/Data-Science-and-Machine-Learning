# %%
import numpy as np
array = np.linspace(0,5,10)
for i in range(1,9):
    print('{.2f}'.format(array[i]))
# Out:
# 0.5555555555555556
# 1.1111111111111112
# 1.6666666666666667
# 2.2222222222222223
# 2.7777777777777777
# 3.3333333333333335
# 3.8888888888888893
# 4.444444444444445
