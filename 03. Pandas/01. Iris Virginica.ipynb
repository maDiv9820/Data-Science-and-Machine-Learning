# %%
import pandas as pd
import numpy as np
dataset = pd.read_csv('https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv')
flower_type = np.unique(dataset['variety'])
for flower in flower_type:
    print(np.sum(dataset['variety'] == flower), end = ' ')
# Out:
# 50 50 50
