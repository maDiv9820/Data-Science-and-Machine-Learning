# %%
import pandas as pd
dataset = pd.read_csv('terrorismData.csv')
df = list(dataset[(dataset['Country'] == 'India')&(dataset['Year'] >= 2014)])
df_india = df[((df['Day'] >= 26)&(df['Month'] == 5)&(df['Year'] == 2014))|((df['Month'] > 5)&(df['Year'] == 2014))|(df['Year'] > 2014)]
df_india
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_8915/4103345712.py in <module>
#       2 dataset = pd.read_csv('terrorismData.csv')
#       3 df = list(dataset[(dataset['Country'] == 'India')&(dataset['Year'] >= 2014)])
# ----> 4 df_india = df[((df['Day'] >= 26)&(df['Month'] == 5)&(df['Year'] == 2014))|((df['Month'] > 5)&(df['Year'] == 2014))|(df['Year'] > 2014)]
#       5 df_india
#
# TypeError: list indices must be integers or slices, not str
