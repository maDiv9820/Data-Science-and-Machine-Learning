# %%
import csv
with open('year2017.csv') as file:
    data = list(csv.reader(file, skipinitialspace = True))
    for values in data[1:11]:
        print(values[3])
# Out:
# Afghanistan
# Sudan
# Democratic Republic of the Congo
# Democratic Republic of the Congo
# Turkey
# Syria
# Pakistan
# Italy
# Turkey
# Turkey
