# %%
import csv
with open('year2017.csv') as file:
    data = csv.DictReader(file, skipinitialspace = True)
    for index in range(10):
        print(data[index])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5819/2929843192.py in <module>
#       3     data = csv.DictReader(file)
#       4     for index in range(10):
# ----> 5         print(data[index])
#
# TypeError: 'DictReader' object is not subscriptable
