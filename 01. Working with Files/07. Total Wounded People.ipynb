# %%
import csv
with open('year2017.csv') as file:
    data = csv.reader(file, skipinitialspace = True)
    wounded = []
    for values in data:
        if values[-6] != '':
            wounded.append(int(values[-6]))
    print(sum(wounded))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6162/1157198731.py in <module>
#       5     for values in data:
#       6         if values[-6] != '':
# ----> 7             wounded.append(int(values[-6]))
#       8     print(sum(wounded))
#
# ValueError: invalid literal for int() with base 10: 'Wounded'
