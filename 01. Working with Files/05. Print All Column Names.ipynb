# %%
import csv
with open('year2017.csv') as file:
    data = list(csv.reader(file))
    for name in data[0]:
        print(name)
# Out:
# Year
# Month
# Day
# Country
# Region
# city
# latitude
# longitude
# AttackType
# Killed
# Wounded
# Target
# Group
# Target_type
# Weapon_type
# casualities
